# %%
import random

# Declarar variables: Piedra, Papel o Tijera

piedra = 1
papel = 2
tijeras = 3


while True:
    
    # Idea 1: cambiar las frases de entrada:
#     opciones_1 = ["Sobres, qué quieres?:", "Sobres, qué escoges?:","Elige una en corto:",
#                   "Caminando y miando:","En calor escoge:","Fierrrru:","Vamo' a darle prro:"]
#     frase_entrada =  random.choice(opciones_1)
#     eleccion_jugador = input({frase_entrada} "'piedra', 'papel' o 'tijeras'")

    # Opciones
    opciones_jugador_gana = ["Ah pasado de lanza...","Cómo le hiciste we?...","Es neta?...",
                            "Chipeaste la compu prro!...","Ya valio barriga, señor v...",
                             "Iralooooooo...","Te crees mucho o qué?...","Mñeh...",
                             "Hubieramos apostado we...","Ahhh mamoncita?..."]
    eleccion_jugador_gana = random.choice(opciones_jugador_gana)
    
    opciones_felicitar_jugador = ["Ya sobres, rúmbele alv...","Otra o qué we?",
                                  "Ganaste. Al cabo que yo ni quería ganar...",
                                 "Sí, sí, mbre. Ganaste. Nomás no te pongas muy mamón",
                                 "Ni pedo, me chingaste","Doble o nada, jalas o qué?"]
    eleccion_felicitar_jugador = random.choice(opciones_felicitar_jugador)
    
    opciones_jugador_pierde = ["Jajaja ahhh se te pasó de lanza la compu","Por morro, ya ves...",
                              "Ni aquí ganas we, allá afuera menos...",
                               "Si esto fuera el FIFA también mlp...","Ya me debes la quincena we..."]
    eleccion_jugador_pierde = random.choice(opciones_jugador_pierde)
    
    opciones_alardeo = ["A HUEVOOOO QUE GANÉ PRRRRRRO","Y con los ojos cerrados mlp",
                        "Ni con COPPEL perdiste tanto, morro","Eres una deshonra para tu calaña"
                       "(Compu en modo bailecito mamón)","Sbs una más"]
    eleccion_alardeo = random.choice(opciones_alardeo)
    
    # Creación de enunciados
    eleccion_jugador = input("\nSobres we, qué quieres?: 'piedra', 'papel' o 'tijeras'")
    piedra_papel_tijera = ["piedra", "papel", "tijeras"]
    eleccion_computadora = random.choice(piedra_papel_tijera)
    print(f"\nEscogiste: {eleccion_jugador}\n\nLa compu escogió: {eleccion_computadora}.\n")
    

    
    # Condicionales para resultados
    if eleccion_jugador == eleccion_computadora:
        print(f"Ambos escogieron: {eleccion_jugador}.\nNadie gana")
    elif eleccion_jugador == "piedra":
        if eleccion_computadora == "tijeras":
            print(f"\n{eleccion_jugador_gana}\nPiedra rompe tijeras! \n{eleccion_felicitar_jugador}\n")
        else:
            print(f"\n{eleccion_jugador_pierde}\nPapel cubre piedra! \n{eleccion_alardeo}\n")
    elif eleccion_jugador == "papel":
        if eleccion_computadora == "piedra":
            print(f"\n{eleccion_jugador_gana}\nPapel cubre piedra! \n{eleccion_felicitar_jugador}\n")
        else:
            print(f"\n{eleccion_jugador_pierde}\nTijeras corta papel! \n{eleccion_alardeo}\n")
    elif eleccion_jugador == "tijeras":
        if eleccion_computadora == "papel":
            print(f"\n{eleccion_jugador_gana}\nTijeras corta papel! \n{eleccion_felicitar_jugador}\n")
        else:
            print(f"\n{eleccion_jugador_pierde}Piedra rompe tijeras! \n{eleccion_alardeo}\n")
        

    otro_juego = input("¿Otra o qué? Sbsbsbsbs (y/n):\n")
    if otro_juego.lower() != "y":
        break
